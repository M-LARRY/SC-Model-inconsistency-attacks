# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import math
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
from federated_learning import *

# %%
# Configuration
num_clients = 5
num_classes = 10
input_shape = (3, 32, 32) 
batch_size = 32
rounds = 5
epochs = 10
model = 2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Download and transform MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261)) # normalization params for CIFAR10
])

cifar_train = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
cifar_test = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Split dataset indices for clients
dataset_size = len(cifar_train)
indices = list(range(dataset_size))
split_size = dataset_size // num_clients

clients_dataloaders = []
for i in range(num_clients):
    start = i * split_size
    end = start + split_size if i < num_clients - 1 else dataset_size
    client_indices = indices[start:end]
    client_subset = Subset(cifar_train, client_indices)
    dataloader = DataLoader(client_subset, batch_size=batch_size, shuffle=True)
    clients_dataloaders.append(dataloader)

print(f"Prepared {num_clients} client dataloaders")

test_loader = DataLoader(dataset=cifar_test, batch_size=64, shuffle=False)
# Out:
# tensor([3])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([7])
# tensor([0])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([0])
# tensor([3])
# tensor([8])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([6])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([8])
# tensor([6])
# tensor([4])
# tensor([6])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([4])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([2])
# tensor([8])
# tensor([0])
# tensor([8])
# tensor([3])
# tensor([5])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([2])
# tensor([9])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([4])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([8])
# tensor([6])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([0])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([8])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([1])
# tensor([8])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([6])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([5])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([3])
# tensor([2])
# tensor([6])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([3])
# tensor([5])
# tensor([2])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([9])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([6])
# tensor([2])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([8])
# tensor([8])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([3])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([4])
# tensor([9])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([5])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([7])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([4])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([6])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([5])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([2])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([4])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([9])
# tensor([2])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([4])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([3])
# tensor([0])
# tensor([5])
# tensor([5])
# tensor([3])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([6])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([5])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([7])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([8])
# tensor([7])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([2])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([7])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([2])
# tensor([9])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([8])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([9])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([4])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([8])
# tensor([8])
# tensor([5])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([1])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([1])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([7])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([4])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([7])
# tensor([5])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([6])
# tensor([2])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([7])
# tensor([9])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([9])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([6])
# tensor([3])
# tensor([5])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([5])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([8])
# tensor([5])
# tensor([6])
# tensor([7])
# tensor([3])
# tensor([2])
# tensor([4])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([8])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([5])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([5])
# tensor([2])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([5])
# tensor([1])
# tensor([4])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([3])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([7])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([8])
# tensor([6])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([8])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([2])
# tensor([7])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([7])
# tensor([5])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([4])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([5])
# tensor([5])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([9])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([9])
# tensor([5])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([0])
# tensor([8])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([8])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([1])
# tensor([5])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([2])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([7])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([9])
# tensor([6])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([4])
# tensor([2])
# tensor([8])
# tensor([3])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([2])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([5])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([2])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([0])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([8])
# tensor([6])
# tensor([5])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([5])
# tensor([0])
# tensor([5])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([2])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([3])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([3])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([6])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([5])
# tensor([1])
# tensor([5])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([5])
# tensor([8])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([3])
# tensor([5])
# tensor([5])
# tensor([5])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([3])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([7])
# tensor([9])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([3])
# tensor([1])
# tensor([9])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([1])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([1])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([6])
# tensor([0])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([1])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([6])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([7])
# tensor([5])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([6])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([6])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([6])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([8])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([7])
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([6])
# tensor([3])
# tensor([0])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([5])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([0])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([8])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([7])
# tensor([7])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([0])
# tensor([4])
# tensor([9])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([0])
# tensor([4])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([4])
# tensor([7])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([9])
# tensor([0])
# tensor([8])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([1])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([0])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([8])
# tensor([4])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([4])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([7])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([5])
# tensor([1])
# tensor([6])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([5])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([4])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([9])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([4])
# tensor([1])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([7])
# tensor([7])
# tensor([2])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([5])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([2])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([6])
# tensor([8])
# tensor([5])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([0])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([4])
# tensor([5])
# tensor([5])
# tensor([5])
# tensor([1])
# tensor([8])
# tensor([7])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([8])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([7])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([8])
# tensor([8])
# tensor([1])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([5])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([4])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([8])
# tensor([6])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([9])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([9])
# tensor([0])
# tensor([2])
# tensor([6])
# tensor([9])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([6])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([7])
# tensor([7])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([3])
# tensor([5])
# tensor([7])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([5])
# tensor([5])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([4])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([1])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([9])
# tensor([5])
# tensor([1])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([4])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([4])
# tensor([5])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([6])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([5])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([3])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([2])
# tensor([7])
# tensor([4])
# tensor([0])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([0])
# tensor([4])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([1])
# tensor([8])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([3])
# tensor([9])
# tensor([2])
# tensor([7])
# tensor([2])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([4])
# tensor([6])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([4])
# tensor([5])
# tensor([2])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([9])
# tensor([2])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([2])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([3])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([7])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([9])
# tensor([0])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([8])
# tensor([7])
# tensor([9])
# tensor([6])
# tensor([2])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([5])
# tensor([6])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([6])
# tensor([8])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([5])
# tensor([0])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([9])
# ...
# tensor([9])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([8])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([7])
# tensor([2])
# tensor([7])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([8])
# tensor([5])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([4])
# tensor([8])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([9])
# tensor([6])
# tensor([5])
# tensor([2])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([2])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([8])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([5])
# tensor([0])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([5])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([4])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([7])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([0])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([4])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([6])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([2])
# tensor([0])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([6])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([6])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([0])
# tensor([5])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([6])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([4])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([6])
# tensor([9])
# tensor([2])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([2])
# tensor([3])
# tensor([2])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([4])
# tensor([8])
# tensor([6])
# tensor([5])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([9])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([3])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([0])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([4])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([8])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([7])
# tensor([3])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([8])
# tensor([8])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([7])
# tensor([8])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([5])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([3])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([8])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([3])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([1])
# tensor([9])
# tensor([6])
# tensor([0])
# tensor([2])
# tensor([6])
# tensor([7])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([4])
# tensor([3])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([0])
# tensor([6])
# tensor([0])
# tensor([9])
# tensor([2])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([2])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([0])
# tensor([7])
# tensor([4])
# tensor([8])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([6])
# tensor([2])
# tensor([6])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([4])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([6])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([2])
# tensor([0])
# tensor([9])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([4])
# tensor([5])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([7])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([6])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([1])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([1])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([9])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([3])
# tensor([5])
# tensor([8])
# tensor([7])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([6])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([7])
# tensor([4])
# tensor([2])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([8])
# tensor([5])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([5])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([3])
# tensor([9])
# tensor([3])
# tensor([5])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([5])
# tensor([6])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([3])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([1])
# tensor([2])
# tensor([0])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([5])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([0])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([7])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([2])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([7])
# tensor([4])
# tensor([4])
# tensor([3])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([0])
# tensor([8])
# tensor([7])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([7])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([5])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([4])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([5])
# tensor([3])
# tensor([8])
# tensor([3])
# tensor([5])
# tensor([1])
# tensor([7])
# Prepared 5 client dataloaders

# %%
global_model, _ = federated_learning(
    clients_dataloaders=clients_dataloaders,
    input_shape=input_shape,
    num_classes=num_classes,
    rounds=rounds,
    epochs=epochs,
    device=device,
    model=model
)

print("Federated learning simulation complete!")
# Out:
# Round 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 global_model, _ = federated_learning(
#       2     clients_dataloaders=clients_dataloaders,
#       3     input_shape=input_shape,
#       4     num_classes=num_classes,
#       5     rounds=rounds,
#       6     epochs=epochs,
#       7     device=device,
#       8     model=model
#       9 )
#      11 print("Federated learning simulation complete!")
#
# File ~/Documenti/Sviluppo/SC-Model-inconsistency-attacks/federated_learning.py:49, in federated_learning(clients_dataloaders, input_shape, num_classes, rounds, epochs, device, model)
#      47     local_model = copy.deepcopy(global_model)
#      48     optimizer = torch.optim.SGD(local_model.parameters(), lr=0.01)
# ---> 49     local_state = local_train(local_model, dataloader, criterion, optimizer, epochs, device)
#      50     local_state_dicts.append(local_state)
#      52 # Aggregate updates from clients
#
# File ~/Documenti/Sviluppo/SC-Model-inconsistency-attacks/federated_learning.py:16, in local_train(model, dataloader, criterion, optimizer, epochs, device)
#      14         outputs = model(inputs)
#      15         loss = criterion(outputs, targets)
# ---> 16         loss.backward()
#      17         optimizer.step()
#      18 return model.state_dict()
#
# File ~/Documenti/Sviluppo/SC-Model-inconsistency-attacks/.venv/lib64/python3.13/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/Documenti/Sviluppo/SC-Model-inconsistency-attacks/.venv/lib64/python3.13/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/Documenti/Sviluppo/SC-Model-inconsistency-attacks/.venv/lib64/python3.13/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
global_model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = global_model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Accuracy: 71.22%

# %%
# save trained model to file
torch.save(global_model.state_dict(), 'trained_model_CIFAR10.pth')
